# %%
# !git clone https://github.com/cwinsor/uml_comp5300.git
# Out:
# Cloning into 'uml_comp5300'...
# remote: Enumerating objects: 411, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 411 (delta 11), reused 20 (delta 11), pack-reused 385
# Receiving objects: 100% (411/411), 2.03 MiB | 15.62 MiB/s, done.
# Resolving deltas: 100% (250/250), done.

# %%
import os
if "ORIGINAL_PYTHONPATH" not in os.environ:
    os.environ['ORIGINAL_PYTHONPATH'] = os.environ['PYTHONPATH']
os.environ['PYTHONPATH'] = os.environ['ORIGINAL_PYTHONPATH']
os.environ['PYTHONPATH'] += ":/content/uml_comp5300/hw6_translation/transformer_mt"
print(f'PYTHONPATH={os.environ["PYTHONPATH"]}')
# Out:
# PYTHONPATH=/env/python:/content/uml_comp5300/hw6_translation/transformer_mt

# %%
import os
os.environ['FOO'] += ":/content/uml_comp5300/hw6_translation/transformer_mt"
# !echo $FOO
# Out:
# "$FOO+bar":blah:blah:blah

# %%
# !echo $FOO
# %env FOO="$FOO+bar"
# !echo $FOO
# Out:
# $(FOO)+bar
# env: FOO="$FOO+bar"
# "$FOO+bar"

# %%
# !echo $PYTHONPATH
# Out:
# /env/python

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# add to PYTHONPATH so we can g
# !cd /content/drive/MyDrive/code_uml/uml_comp5300/hw6_translation; python setup.py

# %%
from transformers import PreTrainedTokenizerFast
from transformer_mt.modeling_transformer import TransfomerEncoderDecoderModel
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-1e8cf5343740> in <module>
# ----> 1 from transformers import PreTrainedTokenizerFast
#       2 from transformer_mt.modeling_transformer import TransfomerEncoderDecoderModel
#
# ModuleNotFoundError: No module named 'transformers'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# You probably need to modify the paths to your tokenizers
# For tokenizers, you need to provide the path to a directory that contains the tokenizer.json file
# For model, you need to provide the path to a directory that contains the model.pt file

folder_path = "/content/drive/MyDrive/code_uml/uml_comp5300/hw6_translation/output_dir_copy_2"
source_tokenizer = PreTrainedTokenizerFast.from_pretrained(folder_path + "/en_tokenizer")
target_tokenizer = PreTrainedTokenizerFast.from_pretrained(folder_path + "de_tokenizer")

run_dir = "../wandb/run-20230322_180023-jyra6nqi/files"
# run_dir = "../output_dir"
model = TransfomerEncoderDecoderModel.from_pretrained(run_dir)
_ = model.eval()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# d:\code_uml\uml_comp5300\hw6_translation\notebooks\03_interact.ipynb Cell 2 in <cell line: 10>()
#       <a href='vscode-notebook-cell:/d%3A/code_uml/uml_comp5300/hw6_translation/notebooks/03_interact.ipynb#W1sZmlsZQ%3D%3D?line=7'>8</a> run_dir = "../wandb/run-20230322_180023-jyra6nqi/files"
#       <a href='vscode-notebook-cell:/d%3A/code_uml/uml_comp5300/hw6_translation/notebooks/03_interact.ipynb#W1sZmlsZQ%3D%3D?line=8'>9</a> # run_dir = "../output_dir"
# ---> <a href='vscode-notebook-cell:/d%3A/code_uml/uml_comp5300/hw6_translation/notebooks/03_interact.ipynb#W1sZmlsZQ%3D%3D?line=9'>10</a> model = TransfomerEncoderDecoderModel.from_pretrained(run_dir)
#      <a href='vscode-notebook-cell:/d%3A/code_uml/uml_comp5300/hw6_translation/notebooks/03_interact.ipynb#W1sZmlsZQ%3D%3D?line=10'>11</a> _ = model.eval()
#
# File G:\My Drive\code_uml\uml_comp5300\hw6_translation\transformer_mt\modeling_transformer.py:566, in TransfomerEncoderDecoderModel.from_pretrained(cls, save_path, map_location)
#     563 if map_location is None and not torch.cuda.is_available():
#     564     map_location = "cpu"
# --> 566 with open(os.path.join(save_path, "model_config.json"), "r") as f:
#     567     config = json.load(f)
#     569 model = cls(**config)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../wandb/run-20230322_180023-jyra6nqi/files\\model_config.json'

# %% [markdown]
# ## Task
#
# Try out your model. Feel free to use your own sentences and to compare the model outputs to Google Translate.
# Find at least three sentences that are translated well, and one that is translated badly.
#
# Feel free to change beam size and max_length parameters.

# %%
input_ids = source_tokenizer.encode("Hallo, mein Hund ist süß", return_tensors="pt")
output_ids = model.generate(
    input_ids,
    max_length=10,
    bos_token_id=target_tokenizer.bos_token_id,
    eos_token_id=target_tokenizer.eos_token_id,
    pad_token_id=target_tokenizer.pad_token_id,
)
target_tokenizer.decode(output_ids[0])
# Out:
# 'Schließ symp, einzuhalten Arafat,, inspiriert Frattini lehnung'
